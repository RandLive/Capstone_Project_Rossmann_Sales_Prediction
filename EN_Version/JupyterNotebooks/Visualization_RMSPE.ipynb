# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg") #Needed to save figures
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\envs\XGBST\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\ProgramData\Anaconda3\envs\XGBST\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\envs\XGBST\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\envs\XGBST\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\envs\XGBST\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
# ...

# %%
plt.rcParams["figure.figsize"] = (18,9)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20)

# %%
xg_0_k3 = 0.11793
xg_1_k3 = 0.11963
xg_2_k3 = 0.11969
xg_3_k3 = 0.12015
xg_4_k3 = 0.11931
xg_5_k3 = 0.12156
xg_6_k3 = 0.11848
xg_Aver_k3 = 0.11710
x_ax = ['12','11','10','9','8','7','6', 'Averaged']
y_ax = np.array([xg_0_k3, xg_1_k3, xg_2_k3, xg_3_k3, xg_4_k3, xg_5_k3, xg_6_k3, xg_Aver_k3])

axes = plt.gca()
axes.set_ylim([0.11,0.126])

_ = sns.barplot(x=x_ax,y=y_ax)
plt.xlabel('max_depth (k=3)', fontsize=30)
plt.ylabel('RMSPE', fontsize=30)
plt.show()

# %%
xg_0_k2_8 = 0.12114
xg_1_k2_8 = 0.11844
xg_2_k2_8 = 0.11820
xg_3_k2_8 = 0.11976
xg_4_k2_8 = 0.11950
xg_5_k2_8 = 0.12059
xg_6_k2_8 = 0.11809
xg_Aver_k2_8 = 0.11711
x_ax = ['12','11','10','9','8','7','6', 'Averaged']
y_ax = np.array([xg_0_k2_8, xg_1_k2_8, xg_2_k2_8, xg_3_k2_8, xg_4_k2_8, xg_5_k2_8, xg_6_k2_8, xg_Aver_k2_8])

axes = plt.gca()
axes.set_ylim([0.11,0.126])

_ = sns.barplot(x=x_ax,y=y_ax)
plt.xlabel('max_depth (k=2.8)', fontsize=30)
plt.ylabel('RMSPE', fontsize=30)
plt.show()

# %%
xg_0_k2_5 = 0.12014
xg_1_k2_5 = 0.11828
xg_2_k2_5 = 0.11802
xg_3_k2_5 = 0.11942
xg_4_k2_5 = 0.11983
xg_5_k2_5 = 0.12170
xg_6_k2_5 = 0.11976
xg_Aver_k2_5 = 0.11708
x_ax = ['12','11','10','9','8','7','6', 'Averaged']
y_ax = np.array([xg_0_k2_5, xg_1_k2_5, xg_2_k2_5, xg_3_k2_5, xg_4_k2_5, xg_5_k2_5, xg_6_k2_5, xg_Aver_k2_5])

axes = plt.gca()
axes.set_ylim([0.11,0.126])

_ = sns.barplot(x=x_ax,y=y_ax)
plt.xlabel('max_depth (k=2.5)', fontsize=30)
plt.ylabel('RMSPE', fontsize=30)
plt.show()

# %%
xg_0_k1_5 = 0.12440
xg_1_k1_5 = 0.12427
xg_2_k1_5 = 0.12142
xg_3_k1_5 = 0.12222

xg_4_k1_5 = 0.12576
xg_5_k1_5 = 0.12461
xg_6_k1_5 = 0.12382
xg_Aver_k1_5 = 0.12127
x_ax = ['12','11','10','9','8','7','6', 'Averaged']
y_ax = np.array([xg_0_k1_5, xg_1_k1_5, xg_2_k1_5, xg_3_k1_5, xg_4_k1_5, xg_5_k1_5, xg_6_k1_5, xg_Aver_k1_5])

axes = plt.gca()
axes.set_ylim([0.11,0.126])

_ = sns.barplot(x=x_ax,y=y_ax)
plt.xlabel('max_depth (k=1.5)', fontsize=30)
plt.ylabel('RMSPE', fontsize=30)
plt.show()

# %%
xg_Aver_k_3 = 0.11710
xg_Aver_k_2_8 = 0.11711
xg_Aver_k_2_5 = 0.11708
xg_Aver_Aver = 0.11687

x_ax = ['Aver_k=3','Aver_k=2.8','Aver_k=2.5','Average of the three']
y_ax = np.array([xg_Aver_k_3,xg_Aver_k_2_8,xg_Aver_k_2_5, xg_Aver_Aver])

axes = plt.gca()
axes.set_ylim([0.1165,0.1172])

_ = sns.barplot(x=x_ax,y=y_ax)
plt.xlabel('different k with averaged value', fontsize=30)
plt.ylabel('RMSPE', fontsize=30)
plt.show()
